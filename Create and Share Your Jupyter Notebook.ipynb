# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Julián Baeza García**
# Currently Account Executive at Bit2Me. Willing to work as a Data Analyst on a crypto company.

# %% [markdown]
# *I am interested in Data Science because I would like to have a deeper understanding of data, how it is obtained and treated. Doing so can help me to interpret the data I'm working with and find new ways to analyze it. Data Science can also help me automate Data Analysis tasks.*

# %% [markdown]
# ### Just a simple sum

# %%
print(10+8)
# Out:
# 18

# %% [markdown]
# <h3> Some of my favorite cities are:</h3>
# <ul>
#     <li>Prague, Czech Republic</li>
#     <li>Krakow, Poland</li>
#     <li>Albir, Alicante</li>
# </ul>
# <table align="left"style="margin: 0 auto; text-align: center;">
#     <tr>
#         <th>City</th>
#         <th>Country</th>
#         <th>Population</th>
#         <th>Photo</th>
#     </tr>
#     <tr>
#         <td>Prague</td>
#         <td>Czech Republic</td>
#         <td>1.3 million</td>
#         <td><img src="https://media.tacdn.com/media/attractions-splice-spp-674x446/0b/e1/1b/2c.jpg" alt="Prague" style="max-width: 200px;"></td>
#     </tr>
#     <tr>
#         <td>Krakow</td>
#         <td>Poland</td>
#         <td>770,000</td>
#         <td><img src="https://krakowbooking.com/wp-content/uploads/2020/05/Night-Main-e1590404626538.jpg" alt="Krakow" style="max-width: 200px;"></td>
#     </tr>
#     <tr>
#         <td>Albir</td>
#         <td>Spain</td>
#         <td>6,200</td>
#         <td><img src="https://alicanteout.com/wp-content/uploads/el-albir.jpg" alt="Albir" style="max-width: 200px;"></td>
#     </tr>
# </table>
